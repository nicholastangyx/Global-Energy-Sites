# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# Data from https://datasets.wri.org/dataset/globalpowerplantdatabase
df = pd.read_csv(r'C:\Users\Rig 1\Desktop\Code\Python Project\Global Power Plant\data\global_power_plant_database.csv')
df
# Out:
# C:\Users\Rig 1\AppData\Local\Temp\ipykernel_49572\2952936566.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\Rig 1\Desktop\Code\Python Project\Global Power Plant\data\global_power_plant_database.csv')
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# ...

# %%
x = df[df.country == 'MYS']
# x.to_csv('x.csv')
x.sum()
# Out:
# C:\Users\Rig 1\AppData\Local\Temp\ipykernel_49572\2529265501.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.sum()
# country                           MYSMYSMYSMYSMYSMYSMYSMYSMYSMYSMYSMYSMYSMYSMYSM...
# country_long                      MalaysiaMalaysiaMalaysiaMalaysiaMalaysiaMalays...
# name                              Batang AlBersiaBukit Palong Solar Power PlantC...
# gppd_idnr                         WRI1000280WRI1000233WRI1026640WRI1000246WRI100...
# capacity_mw                                                                 28794.5
# latitude                                                                   218.9173
# longitude                                                                 5803.1327
# primary_fuel                      HydroHydroSolarGasGasSolarGasSolarGasSolarHydr...
# ...
